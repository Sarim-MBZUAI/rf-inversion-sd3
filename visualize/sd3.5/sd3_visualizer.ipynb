# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from scipy.linalg import sqrtm
from skimage.metrics import structural_similarity
import lpips
from tqdm import tqdm
from sklearn.metrics import roc_curve, auc



class ImageMetricsComparisonSimple:
    def __init__(self, fake_dir, inv_fake_dir, real_dir, inv_real_dir, 
                 device='cuda' if torch.cuda.is_available() else 'cpu'):
        self.fake_dir = fake_dir
        self.inv_fake_dir = inv_fake_dir
        self.real_dir = real_dir
        self.inv_real_dir = inv_real_dir
        self.device = device
        self.target_size = (1024, 1024)
        
        
        self.loss_fn_alex = lpips.LPIPS(net='alex').to(device)

    def calculate_psnr(self, img1, img2):
        if isinstance(img1, Image.Image):
            img1 = img1.resize(self.target_size, Image.Resampling.LANCZOS)
            img1 = np.array(img1)
        if isinstance(img2, Image.Image):
            img2 = img2.resize(self.target_size, Image.Resampling.LANCZOS)
            img2 = np.array(img2)
        
        img1 = img1.astype(np.float64)
        img2 = img2.astype(np.float64)
        
        mse = np.mean((img1 - img2) ** 2)
        if mse == 0:
            return float('inf')
        
        max_pixel = 255.0
        psnr = 20 * np.log10(max_pixel / np.sqrt(mse))
        return psnr

    def calculate_ssim(self, img1, img2):
        if isinstance(img1, Image.Image):
            img1 = img1.resize(self.target_size, Image.Resampling.LANCZOS)
            img1 = np.array(img1)
        if isinstance(img2, Image.Image):
            img2 = img2.resize(self.target_size, Image.Resampling.LANCZOS)
            img2 = np.array(img2)
            
        if img1.dtype != np.uint8:
            img1 = (img1.clip(0, 255) + 0.5).astype(np.uint8)
        if img2.dtype != np.uint8:
            img2 = (img2.clip(0, 255) + 0.5).astype(np.uint8)
            
        if len(img1.shape) == 3:
            img1 = np.mean(img1, axis=2).astype(np.uint8)
        if len(img2.shape) == 3:
            img2 = np.mean(img2, axis=2).astype(np.uint8)
            
        return structural_similarity(img1, img2, data_range=255)

    def calculate_lpips(self, img1, img2):
        if not isinstance(img1, Image.Image):
            img1 = Image.fromarray(img1)
        if not isinstance(img2, Image.Image):
            img2 = Image.fromarray(img2)
            
        img1 = img1.resize(self.target_size, Image.Resampling.LANCZOS)
        img2 = img2.resize(self.target_size, Image.Resampling.LANCZOS)
        
        transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
        ])
        
        img1_tensor = transform(img1).unsqueeze(0).to(self.device)
        img2_tensor = transform(img2).unsqueeze(0).to(self.device)
        
        with torch.no_grad():
            lpips_value = self.loss_fn_alex(img1_tensor, img2_tensor)
        return lpips_value.item()

    def calculate_metrics_for_pair(self, dir1, dir2, desc):
        files = sorted([f for f in os.listdir(dir1) if f.endswith('.png')])
        metrics = {
            'psnr': [], 'ssim': [], 'lpips': [], 'filenames': []
        }
        
        for filename in tqdm(files, desc=desc):
            path1 = os.path.join(dir1, filename)
            path2 = os.path.join(dir2, filename)
            
            if not os.path.exists(path2):
                continue
            
            try:
                img1 = Image.open(path1).convert('RGB')
                img2 = Image.open(path2).convert('RGB')
                
                psnr = self.calculate_psnr(img1, img2)
                ssim = self.calculate_ssim(img1, img2)
                lpips_val = self.calculate_lpips(img1, img2)
                
                if all(x is not None and not np.isnan(x) for x in [psnr, ssim, lpips_val]):
                    metrics['psnr'].append(psnr)
                    metrics['ssim'].append(ssim)
                    metrics['lpips'].append(lpips_val)
                    metrics['filenames'].append(filename)
                
            except Exception:
                continue
        
        return metrics

    def plot_comparative_metrics(self, fake_metrics, real_metrics):
        if len(fake_metrics['filenames']) == 0 or len(real_metrics['filenames']) == 0:
            return

    def plot_comparative_metrics(self, fake_metrics, real_metrics):
        if len(fake_metrics['filenames']) == 0 or len(real_metrics['filenames']) == 0:
            print("Error: No data available to plot metrics. Please check if the input directories contain matching image pairs.")
            return

        fig = plt.figure(figsize=(15, 12))
        gs = plt.GridSpec(3, 2)  # Added an extra row for ROC curve
        
        metrics_list = [
            ('PSNR (Higher is better)', 'psnr', gs[0, 0], True),
            ('SSIM (Higher is better)', 'ssim', gs[0, 1], True),
            ('LPIPS (Lower is better)', 'lpips', gs[1, 0], False)
        ]
        
        # Plot histograms
        for title, metric_name, pos, higher_better in metrics_list:
            ax = fig.add_subplot(pos)
            fake_values = np.array(fake_metrics[metric_name])
            real_values = np.array(real_metrics[metric_name])
            
            fake_values = fake_values[~np.isinf(fake_values)]
            real_values = real_values[~np.isinf(real_values)]
            
            if len(fake_values) > 0 and len(real_values) > 0:
                ax.hist(fake_values, bins=30, alpha=0.5, label='Fake vs Inv_Fake', color='blue')
                ax.hist(real_values, bins=30, alpha=0.5, label='Real vs Inv_Real', color='red')
                ax.set_title(title)
                ax.legend()
                ax.grid(True, alpha=0.3)
                
                fake_stats = f'Fake μ={np.mean(fake_values):.3f}, σ={np.std(fake_values):.3f}'
                real_stats = f'Real μ={np.mean(real_values):.3f}, σ={np.std(real_values):.3f}'
                ax.text(0.02, 0.98, f'{fake_stats}\n{real_stats}',
                    transform=ax.transAxes, va='top', fontsize=8)
            else:
                ax.text(0.5, 0.5, 'No data available', 
                    ha='center', va='center', transform=ax.transAxes)

        # Plot ROC curves
        ax_roc = fig.add_subplot(gs[1, 1])
        metrics_for_roc = ['psnr', 'ssim', 'lpips']
        
        if len(fake_metrics['filenames']) > 0 and len(real_metrics['filenames']) > 0:
            for metric_name in metrics_for_roc:
                # For LPIPS, lower is better so we need to invert the scores
                scores = np.concatenate([fake_metrics[metric_name], real_metrics[metric_name]])
                if metric_name == 'lpips':
                    scores = -scores  # Invert LPIPS scores since lower is better
                
                # Create labels: 1 for fake, 0 for real
                labels = np.concatenate([np.ones(len(fake_metrics[metric_name])), 
                                    np.zeros(len(real_metrics[metric_name]))])
                
                # Remove inf values
                valid_idx = ~np.isinf(scores)
                scores = scores[valid_idx]
                labels = labels[valid_idx]
                
                if len(scores) > 0 and len(np.unique(labels)) > 1:
                    fpr, tpr, _ = roc_curve(labels, scores)
                    roc_auc = auc(fpr, tpr)
                    ax_roc.plot(fpr, tpr, label=f'{metric_name.upper()} (AUC = {roc_auc:.2f})')
            
            ax_roc.plot([0, 1], [0, 1], 'k--')
            ax_roc.set_title('ROC Curves')
            ax_roc.set_xlabel('False Positive Rate')
            ax_roc.set_ylabel('True Positive Rate')
            ax_roc.legend()
            ax_roc.grid(True, alpha=0.3)
        else:
            ax_roc.text(0.5, 0.5, 'No data available for ROC curves', 
                    ha='center', va='center')

        # Plot correlation matrix
        ax_corr = fig.add_subplot(gs[2, :])  # Make correlation matrix span both columns
        metrics_data = []
        metric_labels = ['PSNR', 'SSIM', 'LPIPS']
        for metric in ['psnr', 'ssim', 'lpips']:
            combined_metric = np.concatenate([fake_metrics[metric], real_metrics[metric]])
            combined_metric = combined_metric[~np.isinf(combined_metric)]
            if len(combined_metric) > 0:
                metrics_data.append(combined_metric)
        
        if len(metrics_data) > 0:
            metrics_data = np.array(metrics_data)
            corr_matrix = np.corrcoef(metrics_data)
            
            im = ax_corr.imshow(corr_matrix, cmap='coolwarm', aspect='auto')
            ax_corr.set_title('Metrics Correlation')
            
            ax_corr.set_xticks(range(len(metric_labels)))
            ax_corr.set_yticks(range(len(metric_labels)))
            ax_corr.set_xticklabels(metric_labels)
            ax_corr.set_yticklabels(metric_labels)
            
            for i in range(len(metric_labels)):
                for j in range(len(metric_labels)):
                    ax_corr.text(j, i, f'{corr_matrix[i, j]:.2f}', 
                            ha='center', va='center')
            
            plt.colorbar(im, ax=ax_corr)
        else:
            ax_corr.text(0.5, 0.5, 'No data available', 
                    ha='center', va='center', transform=ax_corr.transAxes)
        
        plt.tight_layout()
        plt.savefig('metrics_comparison.png', dpi=300, bbox_inches='tight')
        plt.close()
        
        self.save_numerical_results(fake_metrics, real_metrics)

    def save_numerical_results(self, fake_metrics, real_metrics):
        with open('metrics_results.txt', 'w') as f:
            f.write("=== Numerical Results ===\n\n")
            
            for metric in ['psnr', 'ssim', 'lpips']:
                f.write(f"\n{metric.upper()} Statistics:\n")
                
                fake_values = np.array(fake_metrics[metric])
                real_values = np.array(real_metrics[metric])
                
                fake_values = fake_values[~np.isinf(fake_values)]
                real_values = real_values[~np.isinf(real_values)]
                
                f.write(f"Fake vs Inv_Fake:\n")
                f.write(f"  Mean: {np.mean(fake_values):.4f}\n")
                f.write(f"  Std:  {np.std(fake_values):.4f}\n")
                f.write(f"  Min:  {np.min(fake_values):.4f}\n")
                f.write(f"  Max:  {np.max(fake_values):.4f}\n")
                
                f.write(f"Real vs Inv_Real:\n")
                f.write(f"  Mean: {np.mean(real_values):.4f}\n")
                f.write(f"  Std:  {np.std(real_values):.4f}\n")
                f.write(f"  Min:  {np.min(real_values):.4f}\n")
                f.write(f"  Max:  {np.max(real_values):.4f}\n")


def main():
    base_dir = '/shared/shashmi/inversion/inversion/SD3.5'
    fake_dir = os.path.join(base_dir, 'fake')
    inv_fake_dir = os.path.join(base_dir, 'inv_fake')
    real_dir = os.path.join(base_dir, 'real')
    inv_real_dir = os.path.join(base_dir, 'inv_real')
    
    metrics_calc = ImageMetricsComparisonSimple(
        fake_dir, inv_fake_dir, real_dir, inv_real_dir
    )
    
    fake_metrics = metrics_calc.calculate_metrics_for_pair(fake_dir, inv_fake_dir, "Fake vs Inv_Fake")
    real_metrics = metrics_calc.calculate_metrics_for_pair(real_dir, inv_real_dir, "Real vs Inv_Real")
    metrics_calc.plot_comparative_metrics(fake_metrics, real_metrics)

if __name__ == "__main__":
    try:
        torch.multiprocessing.set_start_method('spawn')
    except RuntimeError:
        pass
    main()
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /shared/shashmi/conda_envs/inverter/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /shared/shashmi/conda_envs/inverter/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /shared/shashmi/conda_envs/inverter/lib/python3.10/site-packages/lpips/lpips.py:107: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(model_path, map_location='cpu'), strict=False)
# Loading model from: /shared/shashmi/conda_envs/inverter/lib/python3.10/site-packages/lpips/weights/v0.1/alex.pth
# Fake vs Inv_Fake: 100%|██████████| 1279/1279 [12:33<00:00,  1.70it/s]
# Real vs Inv_Real: 100%|██████████| 1271/1271 [13:32<00:00,  1.56it/s]

# %%
import os
import shutil
import random

def get_common_files(dir1, dir2):
    """Get list of filenames that exist in both directories"""
    files1 = set(os.listdir(dir1))
    files2 = set(os.listdir(dir2))
    return list(files1.intersection(files2))

def copy_paired_images(source_dir, dest_dir, num_pairs=10):
    """
    Copy specified number of image pairs maintaining the correspondence between
    fake/inv_fake and real/inv_real folders.
    """
    # Create destination directory if it doesn't exist
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)
    
    # Create all required folders
    for folder in ['fake', 'inv_fake', 'real', 'inv_real']:
        os.makedirs(os.path.join(dest_dir, folder), exist_ok=True)
    
    # Get common files between fake and inv_fake
    fake_path = os.path.join(source_dir, 'fake')
    inv_fake_path = os.path.join(source_dir, 'inv_fake')
    fake_pairs = get_common_files(fake_path, inv_fake_path)
    
    # Get common files between real and inv_real
    real_path = os.path.join(source_dir, 'real')
    inv_real_path = os.path.join(source_dir, 'inv_real')
    real_pairs = get_common_files(real_path, inv_real_path)
    
    # Select random samples
    if len(fake_pairs) < num_pairs:
        print(f"Warning: Only {len(fake_pairs)} matching fake/inv_fake pairs found. Using all of them.")
        selected_fake_pairs = fake_pairs
    else:
        selected_fake_pairs = random.sample(fake_pairs, num_pairs)
        
    if len(real_pairs) < num_pairs:
        print(f"Warning: Only {len(real_pairs)} matching real/inv_real pairs found. Using all of them.")
        selected_real_pairs = real_pairs
    else:
        selected_real_pairs = random.sample(real_pairs, num_pairs)
    
    # Copy fake/inv_fake pairs
    for filename in selected_fake_pairs:
        # Copy fake image
        shutil.copy2(
            os.path.join(fake_path, filename),
            os.path.join(dest_dir, 'fake', filename)
        )
        # Copy corresponding inv_fake image
        shutil.copy2(
            os.path.join(inv_fake_path, filename),
            os.path.join(dest_dir, 'inv_fake', filename)
        )
        print(f"Copied fake pair: {filename}")
    
    # Copy real/inv_real pairs
    for filename in selected_real_pairs:
        # Copy real image
        shutil.copy2(
            os.path.join(real_path, filename),
            os.path.join(dest_dir, 'real', filename)
        )
        # Copy corresponding inv_real image
        shutil.copy2(
            os.path.join(inv_real_path, filename),
            os.path.join(dest_dir, 'inv_real', filename)
        )
        print(f"Copied real pair: {filename}")

# Set paths
current_dir = "/shared/shashmi/inversion/inversion/SD3"
demo_dir = os.path.join(os.path.dirname(current_dir), "sd3_demo")

# Execute the copying
copy_paired_images(current_dir, demo_dir, 100)

print("\nProcess completed! Check the sd3_demo folder for the copied image pairs.")
# Out:
# Copied fake pair: people_with_their_head_covered_on_a_motorbike_068db080f5.png
# Copied fake pair: a_red_bus_that_has_stuff_wrote_on_the_outside_e8a7ceee81.png
# Copied fake pair: A_skier_standing_behind_a_difficulty_level_sign_on_da34a5a4ae.png
# Copied fake pair: a_train_on_a_train_track_at_a_station__02de4d0786.png
# Copied fake pair: An_unfinished_bathroom_with_a_boarded_window_and_e_1c8628bb4f.png
# Copied fake pair: A_small_her_of_sheep_gathered_on_a_lawn_in_front_o_17c7e3c548.png
# Copied fake pair: A_city_train_as_it_travels_down_the_tracks__0ed76a84c6.png
# Copied fake pair: An_old_brick_city_has_water_and_a_clock_tower__2cdbb626d9.png
# Copied fake pair: A_white_bus_driving_down_a_street_next_to_trees__39d06f449a.png
# Copied fake pair: A_woman_sitting_on_a_bench_in_a_field_in_front_of__6b172362cc.png
# Copied fake pair: A_biplane_takes_flight_on_a_sunny_day_fbf9235db7.png
# Copied fake pair: A_Virgin_Records_train_next_to_a_blue__yellow_and__b66ef7639d.png
# Copied fake pair: Blurred_image_of_motorized_scooters_on_a_wooded_ro_c657a8ae69.png
# Copied fake pair: A_United_jet_liner_flying_through_the_air__94456a88a5.png
# Copied fake pair: A_woman_sits_on_a_table_and_portrays_a_time_gone_b_87cf7cf21d.png
# Copied fake pair: Train_conductor_standing_on_a_moving_train_next_to_b8275235ae.png
# Copied fake pair: a_man_sitting_on_a_motorcycle_in_a_bike_shop_c6736a4b6e.png
# Copied fake pair: an_airport_with_one_plane_flying_away_and_the_othe_cc945d6b09.png
# Copied fake pair: A_woman_holding_an_umbrella_standing_next_to_a_bla_735aeba852.png
# Copied fake pair: A_couch_on_the_side_of_the_street_with_a_televisio_0a55e3677d.png
# Copied fake pair: A_train_ambling_down_the_tracks_with_shrubbery_on__d29d8cb33a.png
# Copied fake pair: A_man_sitting_on_a_bench_next_to_a_slug__1f04cb19b3.png
# Copied fake pair: older_women_sit_on_a_bench__with_one_of_the_women__85e3819a47.png
# Copied fake pair: Three_giraffes_feed_from_a_basket_hanging_off_a_tr_e26e41641c.png
# Copied fake pair: A_couple_of_giraffe_standing_next_to_a_forest__5833d40672.png
# Copied fake pair: An_oxen_looking_at_a_giraffe_near_some_trees__4cdaf7a16e.png
# Copied fake pair: a_number_of_books_and_magazines_near_a_laptop_56832fe1d2.png
# Copied fake pair: There_are_two_different_street_signs_together_in_a_2f54211e45.png
# Copied fake pair: A_couple_of_sheep_sitting_on_top_of_a_lush_green_g_5606b49680.png
# Copied fake pair: A_bike_parked_on_top_of_a_cement_floor__513c2e5b73.png
# Copied fake pair: A_giraffe_walking_in_a_sandy_enclosure__f02959d69a.png
# Copied fake pair: A_white_kitchen_with_marble_countertops_and_stone__71e6ac3fb4.png
# Copied fake pair: A_close_up_of_a_red_fire_hydrant_next_to_a_light_p_77b673925d.png
# Copied fake pair: A_white_and_red_bus_is_traveling_down_a_road__6c7ea2310f.png
# Copied fake pair: The_retro_bicycle_shop_is_actually_three_stories_h_a5e50e667f.png
# Copied fake pair: A_couple_of_giraffe_standing_next_to_each_other__fd9c96e09c.png
# Copied fake pair: A_man_in_tie__black_coat_and_a_hat__3ce6ca038f.png
# Copied fake pair: A_store_selling_both_ripe_and_unripe_bananas__6720ebe2d9.png
# Copied fake pair: A_woman_standing_in_front_of_a_bathroom_mirror_tak_38988ad7a3.png
# Copied fake pair: A_rose_blooms_next_to_a_train_track__bf3e310ae4.png
# Copied fake pair: A_very_tall_church_tower_with_a_clock_on_the_side__de1a2c9e07.png
# Copied fake pair: A_yellow_striped_cat_sitting_on_a_bathroom_sink__4c764bcc53.png
# Copied fake pair: There_is_a_toilet_in_a_narrow_bathroom__03673a43c9.png
# Copied fake pair: Three_white_storks_with_black_legs_and_beaks_wadin_c91f08b06e.png
# Copied fake pair: There_is_a_bird_perched_on_top_of_a_sign_with_a_bo_3edaf97cb4.png
# Copied fake pair: THERE_IS_A_PARK_BENCH_FACING_A_SNOW_COVERED_MOUNTA_c74600ed83.png
# Copied fake pair: An_empty_city_street_surrounded_by_stores_and_shop_75c9569fea.png
# Copied fake pair: A_traffic_light_sitting_next_to_a_street_lined_wit_636441458e.png
# Copied fake pair: A_city_bus_traveling_down_a_rod_next_to_a_stadium__c1b383dd37.png
# Copied fake pair: A_woman_standing_next_to_a_standing_toilet__8a8fce86da.png
# Copied fake pair: close_up_of_a_microwave__oven__and_a_range_29d0d0f739.png
# Copied fake pair: A_white_sink_on_a_counter_in_a_room__09d13ef2a5.png
# Copied fake pair: A_red_bus_driving_past_a_group_of_passengers__6cae218428.png
# Copied fake pair: A_public_bus_driving_on_a_city_street__4d0101e3e8.png
# Copied fake pair: A_boat_floating_in_a_harbor_of_a_very_large_city__86d798b644.png
# Copied fake pair: Man_in_boxers_on_couch_with_two_laptops_1c318d7a21.png
# Copied fake pair: a_person_and_a_dog_in_a_fake_train_ef5b08d7ef.png
# Copied fake pair: a_ram_is_looking_at_the_camera_and_standing_on_som_f380736c61.png
# Copied fake pair: An_airplane_is_flying_against_a_partly_cloudy_sky__77dc2fd6a2.png
# Copied fake pair: A_kitchen_refrigerator_with_numerous_pictures_held_148671218c.png
# Copied fake pair: A_kitchen_with_a_sink__bottles__jars_and_a_dishwas_3c9301db07.png
# Copied fake pair: A_passenger_train_is_going_across_a_bridge_b91bb3c9ee.png
# Copied fake pair: Three_red_stoplights_against_the_background_of_a_s_08586d51c2.png
# Copied fake pair: A_guy_rides_a_bike_in_a_race_and_has_fun_67351412ab.png
# Copied fake pair: Someone_riding_a_skateboard_down_a_bunch_of_stairs_a0e7127388.png
# Copied fake pair: An_old__weathered_street_sign_that_says_One_Way_656df88bd0.png
# Copied fake pair: A_man_with_a_TV_in_the_middle_of_no_where__e7dbe2bd30.png
# Copied fake pair: A_motorcycle_parked_next_to_a_yellow_thing_and_tre_e002c2189a.png
# Copied fake pair: Two_pieces_of_fruit_sitting_on_a_plate_beside_a_st_728df6c5d2.png
# Copied fake pair: A_man_talking_on_a_cell_phone_walking_an_orange_bi_2123037003.png
# Copied fake pair: A_street_sign_showing_what_roads_go_which_ways__4c91efde5c.png
# Copied fake pair: A_white_pickup_truck_waiting_at_a_red_light__824eb26511.png
# Copied fake pair: A_yellow_train_traveling_past_a_field_next_to_a_fo_f0ff8ec709.png
# Copied fake pair: Red_train_at_a_stop_and_a_man_that_is_waiting___663fc23fe9.png
# Copied fake pair: Black_and_white_photo_of_a_trolley_car__128deca65a.png
# Copied fake pair: A_man_with_glasses_riding_in_a_car_with_an_adorabl_f789150e48.png
# Copied fake pair: Two_cars_driving_down_a_street_next_to_a_green_bus_d6be38f7e1.png
# Copied fake pair: People_walking_around_downtown_and_a_man_riding_hi_65cd0e512e.png
# Copied fake pair: A_large_jetliner_sitting_on_top_of_an_airport_tarm_08d38281fb.png
# Copied fake pair: Well_decorated_restroom_with_sink_and_chair_for_si_be3594fc64.png
# Copied fake pair: A_herd_of_sheep_standing_on_top_of_snow_covered_fi_ca19fceb3a.png
# Copied fake pair: a_number_of_giraffes_in_a_field_near_trees__db50da0708.png
# Copied fake pair: A_giraffe_standing_next_to_a_pile_of_dead_wood__4eb40dde72.png
# Copied fake pair: The_kitchen_appears_to_be_tidy_with_the_dishes_dry_9c3937d3ea.png
# Copied fake pair: A_white_motorcycle_is_next_to_a_store_front_that_s_201a505ee9.png
# Copied fake pair: A_line_of_buses_in_a_parking_lot_with_people_stand_3ba0ba77b0.png
# Copied fake pair: A_lot_of_thought_went_into_decorating_this_rustic__70765e084b.png
# Copied fake pair: A_cat_sitting_on_top_of_a_a_black_car__fa368634eb.png
# Copied fake pair: A_grey_van_in_front_if_a_parking_meter_that_takes__7ca31003b1.png
# Copied fake pair: A_woman_watching_TV_with_an_arm_reaching_from_unde_c50c8f9f2e.png
# Copied fake pair: A_cluttered_bathroom_with_a_toilet_and_sink__e2c804cff4.png
# Copied fake pair: A_large_truck_on_the_side_of_a_street__82b938ee96.png
# Copied fake pair: People_sitting_on_a_bench_watching_a_soccer_game__280cd9b70e.png
# Copied fake pair: The_back_of_a_large__blue_motorcycle_and_rider_d208cda5a2.png
# Copied fake pair: a_bunch_of_green_bananas_and_some_ripe_bananas_nex_3d7ede4251.png
# Copied fake pair: A_double_decker_bus_traveling_down_the_street_in_t_17d61e3b71.png
# Copied fake pair: A_giraffe_and_several_elephants_at_the_water_s_edg_ffda9c873b.png
# Copied fake pair: A_couple_of_people_in_wet_suits_standing_by_surfbo_1d59221567.png
# Copied fake pair: A_fighter_is_jet_flying_through_the_clouds_e435b75522.png
# Copied fake pair: A_very_cute_black_dog_by_a_yellow_fire_hydrant__b13b10d3a4.png
# Copied real pair: Two_men_riding_on_a_motorcycle_with_a_young_girl__e0c1601c89.png
# Copied real pair: A_man_in_glasses_wearing_a_shirt_and_tie__d79c13bf5d.png
# Copied real pair: It_s_wondrous_how_that_big_airplane_manages_to_sta_5b79d31b3b.png
# Copied real pair: People_standing_around_looking_at_a_small_train_on_45a0b832ab.png
# Copied real pair: A_man_standing_next_to_a_bike_inside_of_a_building_4a1c72e32b.png
# Copied real pair: A_modern_bathroom_is_shown_with_a_square_sink__6021a7fac6.png
# Copied real pair: A_lady_walks_a_child_towards_a_bus_parked_in_a_har_b9df0a2f57.png
# Copied real pair: Top_of_a_fire_hydrant_covered_in_pink_paint__e73cd7a072.png
# Copied real pair: A_herd_of_white_sheep_standing_on_top_of_a_green_f_389645f7d0.png
# Copied real pair: A_boy_playing_a_multicolored_piano_on_the_street__ed5bbcf1ce.png
# Copied real pair: A_birthday_boy_with_car_shaped_cake_and_candles_on_675b7262ff.png
# Copied real pair: A_bath_tub_sitting_next_to_a_white_sink__b9a4527dfa.png
# Copied real pair: A_group_of_various_farm_animals_together_in_front__5ec45fc786.png
# Copied real pair: A_toilet_and_a_sink_in_small_bathroom__c5908c88e3.png
# Copied real pair: View_from_a_train_car_of_passing_tracks_and_trees__042635e577.png
# Copied real pair: A_pond_with_various_birds_and_ducks_swimming__fc074d160e.png
# Copied real pair: a_cell_phone_painted_on_a_wall_near_a_bike_a5013834b7.png
# Copied real pair: A_group_of_sheep_grazing_on_a_roadside_c8dc92d6c0.png
# Copied real pair: A_small_bathroom_with_focus_on_the_shower_curtain__f572c92902.png
# Copied real pair: A_stop_sign_posed_on_a_pier_next_to_a_lake__2e3b8ad67d.png
# Copied real pair: A_close_up_of_an_orange_in_a_red_serving_bowl__05d9e19b62.png
# Copied real pair: A_building_with_a_large_circular_window_that_has_a_17f8f69a06.png
# Copied real pair: A_woman_cooking_in_a_skillet_on_the_stove__dea95a47fc.png
# Copied real pair: A_man_taking_a_picture_of_his_reflection_in_the_ba_44c7922f90.png
# Copied real pair: A_train_traveling_past_a_brick_wall_near_a_tank__cf1b55cc89.png
# Copied real pair: A_toilet_and_urinal_side_by_side_in_a_bathroom__8e055c6ebd.png
# Copied real pair: A_yellow_bench_sitting_in_a_field_next_to_trees_an_a819d9f102.png
# Copied real pair: a_white_toilet_is_laying_on_its_side_on_the_ground_d17bd75746.png
# Copied real pair: Four_bowls_containing_fruits_and_vegetables_arrang_551068a242.png
# Copied real pair: A_giraffe_standing_in_a_lush_green_field__704766313d.png
# Copied real pair: a_bathroom_view_of_a_tiolet_and_sink__48b99b8adc.png
# Copied real pair: a_street_sign_attached_to_a_metal_pole_next_to_a_s_85a7e40ee4.png
# Copied real pair: Banana_slices_and_peanut_butter_on_a_blue_plate__161427444a.png
# Copied real pair: A_computer__keyboard_and_mouse_sitting_on_a_desk__d328d869e1.png
# Copied real pair: A_group_of_chefs_displaying_a_large_airplane_cake__002db7e80d.png
# Copied real pair: there_are_two_cats_that_are_laying_inside_of_a_tub_190cc6cd14.png
# Copied real pair: A_motorcycle_parked_in_a_parking_lot_next_to_a_car_4ba14231b6.png
# Copied real pair: There_is_a_motorcycle_parked_against_a_wall__b28e93c7bd.png
# Copied real pair: Several_young_boys_sitting_in_the_library_using_la_2db3111de8.png
# Copied real pair: Two_trains_sitting_on_parallel_tracks_waiting_at_a_49024153f6.png
# Copied real pair: A_pile_of_toilet_paper_sitting_on_top_of_a_toilet__09be5c4c44.png
# Copied real pair: A_lake_is_flooded_over_its_banks_several_inches_an_9c939cf186.png
# Copied real pair: A_mirror_and_soap_dispenser_in_a_bathroom__52671d9646.png
# Copied real pair: A_bathroom_showing_sink__toilet_and_shower__7bb2e3c31b.png
# Copied real pair: a_cyclist_with_a_motorbike_moving_very_fast_d6a58a2a42.png
# Copied real pair: A_couple_of_men_standing_near_a_sailboat__b78cff3b1c.png
# Copied real pair: The_view_from_the_airplane_shows_a_mountain_range__efbb5fbc86.png
# Copied real pair: An_airplane_on_a_large_field_stand_on_the_ground___11601be7a1.png
# Copied real pair: A_giraffe_that_is_standing_in_the_grass__3a1e31a020.png
# Copied real pair: A_giraffe_walking_in_a_sandy_enclosure__8190778b6b.png
# Copied real pair: A_large_white_double_decker_bus_traveling_past_a_t_a4dd71f7d6.png
# Copied real pair: a_bedroom_with_a_cluttered_desk_and_a_messy_bed__0cfad03c0a.png
# Copied real pair: Public_bus_driving_on_a_street_in_Hong_Kong__b19758fe51.png
# Copied real pair: A_train_pulling_into_a_station_with_a_red_bench_se_e97abbc43d.png
# Copied real pair: A_long_passenger_train_traveling_through_a_rural_c_fed9c51008.png
# Copied real pair: A_group_of_people_looking_at_an_elephant__49382b7f5f.png
# Copied real pair: A_fire_hydrant_is_painted_to_look_like_a_dalmation_4c99b0a936.png
# Copied real pair: there_are_many_rocks_on_the_side_of_this_road_a95b63ae84.png
# Copied real pair: A_white_bowl_sitting_on_top_of_a_table__00c2b69bcb.png
# Copied real pair: A_kitten_eating_food_out_of_a_dish_on_the_kitchen__5be332cb21.png
# Copied real pair: A_train_ambling_down_the_tracks_with_shrubbery_on__8b9c8afa9b.png
# Copied real pair: A_cop_car_parked_in_front_of_a_white_fire_hydrant__8c4f7ba610.png
# Copied real pair: a_wire_with_a_street_light_hanging_from_it_50e65039ab.png
# Copied real pair: A_bird_flying_solo_over_a_large_body_of_water__e83893d401.png
# Copied real pair: A_large_clock_on_the_side_of_a_building_has_biblic_cbcd3ae2b7.png
# Copied real pair: Sheep_in_the_process_of_getting_sheered_of_their_w_94471b1d78.png
# Copied real pair: a_sign_on_a_beach_at_sun_set_6383aa7384.png
# Copied real pair: A_small_dog_on_a_leach_sitting_near_a_window__0fc5409491.png
# Copied real pair: A_police_vehicle_is_driving_on_a_city_street__42bc4a9581.png
# Copied real pair: The_airplane_is_taking_off_the_runway_at_the_airpo_969ff3ac0c.png
# Copied real pair: A_white_and_blue_city_bus_traveling_down_a_city_st_b922f317b3.png
# Copied real pair: A_small_airplane_is_flying_against_the_blue_sky__a78ac999f2.png
# Copied real pair: A_mini_car_mouse_is_sitting_on_a_mousepad_with_the_3d68878754.png
# Copied real pair: A_gray_day_at_a_park_with_a_stone_bench__d76658c9aa.png
# Copied real pair: A_train_coming_out_of_a_bridge_next_to_a__river__c69dfa8765.png
# Copied real pair: This_is_a_case_full_of_yellow_bananas___434cdc0035.png
# Copied real pair: a_surveillance_camera_attached_to_a_building_with__70635605c0.png
# Copied real pair: A_giraffe_looking_over_the_corral_fence_in_his_zoo_0276f8c276.png
# Copied real pair: Two_computers_sitting_on_top_of_a_wooden_desk__47209e0b6d.png
# Copied real pair: An_old_man_holding_a_plaque_next_to_a_motorcycle__f9dbb9a019.png
# Copied real pair: A_bunch_of_animals_in_a_grassy_area__3ff468ff31.png
# Copied real pair: A_street_sign_with_the_name_of_two_streets_and_a_s_89c3950866.png
# Copied real pair: A_little_boy_wearing_a_hat_and_leather_boots__4efbb626d9.png
# Copied real pair: Adults_on_motorcycles_with_car_and_crowd_on_street_47a1688d2f.png
# Copied real pair: A_giraffe_standing_in_the_middle_of_a_field__551426a5bf.png
# Copied real pair: This_is_what_is_left_of_a_kitchen_in_an_abandoned__9b2fb8b10e.png
# Copied real pair: A_trian_sitting_next_to_three_other_trains_near_a__2b45fb7709.png
# Copied real pair: A_flock_of_birds_flying_over_a_body_of_water__4e2562b07c.png
# Copied real pair: some_cars_on_a_wet_street_buildings_and_traffic_li_4754067497.png
# Copied real pair: a_sink_in_a_bathroom_with_a_shaver_and_personal_hy_2ef44f74de.png
# Copied real pair: a_close_up_of_a_bath_room_counter_with_items_1ff8129d06.png
# Copied real pair: A_sidewalk_sitting_along_side_of_a_street_under_a__ed1d67ed2e.png
# Copied real pair: A_toilet_is_sitting_amongst_things_have_been_aband_b0ba115b86.png
# Copied real pair: a_man_that_is_riding_a_bike_on_some_concrete__e2279c9675.png
# Copied real pair: a_big_bus_driving_down_the_road_next_to_another_bu_0b3b46a35d.png
# Copied real pair: A_microwave_with_a_bowl_of_food_inside_it__507f4805f2.png
# Copied real pair: A_jet_is_flying_through_the_air_leaving_smoke_behi_c4965a4bb9.png
# Copied real pair: A_man_on_a_bike_looking_at_a_line_of_semi_trucks_i_ba28c146e5.png
# Copied real pair: A_group_of_men_standing_in_a_large_kitchen__539b95ecb7.png
# Copied real pair: A_cubicle_with_two_computers_at_the_desk___7eb2912d04.png
#
# Process completed! Check the sd3_demo folder for the copied image pairs.
