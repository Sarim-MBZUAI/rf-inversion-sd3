# %%
import os
import re

def sanitize_filename(filename):
    """
    Convert a string into a valid filename by:
    1. Removing or replacing invalid characters
    2. Truncating length to avoid too long filenames
    3. Ensuring the filename is unique and valid
    """
    # Remove or replace invalid filename characters
    filename = re.sub(r'[<>:"/\\|?*]', '', filename)
    # Replace spaces and multiple underscores with single underscore
    filename = re.sub(r'\s+', '_', filename)
    # Remove dots from the end of the filename
    filename = filename.rstrip('.')
    # Truncate to reasonable length (max 100 chars)
    filename = filename[:100]
    return filename.lower()

def rename_images(prompt_file, image_dir):
    """
    Rename images in image_dir based on prompts in prompt_file.
    """
    # Read prompts
    with open(prompt_file, 'r') as f:
        prompts = [line.strip() for line in f.readlines()]
    
    # Get list of image files
    image_files = sorted([f for f in os.listdir(image_dir) if f.endswith(('.png', '.jpg', '.jpeg'))])
    
    # Dictionary to keep track of duplicate filenames
    filename_count = {}
    
    print(f"Found {len(image_files)} images and {len(prompts)} prompts")
    
    # Rename files
    for i, (image_file, prompt) in enumerate(zip(image_files, prompts)):
        if not prompt.strip():  # Skip empty prompts
            continue
            
        # Create new filename from prompt
        base_filename = sanitize_filename(prompt)
        
        # Handle duplicate filenames
        if base_filename in filename_count:
            filename_count[base_filename] += 1
            new_filename = f"{base_filename}_{filename_count[base_filename]}.png"
        else:
            filename_count[base_filename] = 0
            new_filename = f"{base_filename}.png"
        
        # Full paths
        old_path = os.path.join(image_dir, image_file)
        new_path = os.path.join(image_dir, new_filename)
        
        # Rename file
        try:
            os.rename(old_path, new_path)
            print(f"Renamed: {image_file} -> {new_filename}")
        except Exception as e:
            print(f"Error renaming {image_file}: {str(e)}")

# Example usage
prompt_file = "/shared/shashmi/sd3.5_generated_images/sd3_hard_examples_prompts.txt"
image_dir = "/shared/shashmi/dawoud_dataset/sd3.5_generated_examples_hard_medium/sd3_hard_examples"

rename_images(prompt_file, image_dir)
# Out:
# Found 225 images and 225 prompts
# Renamed: 000000.png -> a_pink_toilet_and_a_pink_bath_tub_in_the_bathroom.png
# Renamed: 000001.png -> a_busy_chinese_market_crowded_at_night.png
# Renamed: 000002.png -> a_bathroom_with_a_stained_glass_and_stone_wall_and.png
# Renamed: 000003.png -> a_bathtub_with_candles_lit_up_around_it_and_a_stoo.png
# Renamed: 000004.png -> a_bench_overlooks_a_lush_green_valley_below.png
# Renamed: 000005.png -> a_bench_that_is_beautifully_shaded_by_a_tree.png
# Renamed: 000006.png -> a_big_city_street_at_night_with_the_ghost_of_a_tax.png
# Renamed: 000007.png -> a_bird_flying_through_the_air_while_flapping_it_s.png
# Renamed: 000008.png -> a_bird_is_sitting_on_a_berry_bush.png
# Renamed: 000009.png -> a_bird_that_is_sitting_on_top_of_a_branch.png
# Renamed: 000010.png -> a_bird_that_is_sitting_on_top_of_a_tree.png
# Renamed: 000011.png -> a_black_and_white_photograph_of_a_plane_with_many.png
# Renamed: 000012.png -> a_black_lab_waits_at_a_picnic_table_for_it_s_maste.png
# Renamed: 000013.png -> a_blue_and_black_motorcycle_has_a_leather_seat.png
# Renamed: 000014.png -> a_bright_blue_fire_hydrant_is_on_a_brick_sidewalk.png
# Renamed: 000015.png -> a_bus_driver_cleans_off_the_windshield_of_the_bus.png
# Renamed: 000016.png -> a_bus_yard_filled_with_yellow_school_buses_parked.png
# Renamed: 000017.png -> a_busy_city_street_with_dimly_lit_trees_at_night.png
# Renamed: 000018.png -> a_cat_that_is_by_a_bicycle_wheel.png
# Renamed: 000019.png -> a_city_street_at_night_with_a_green_signal.png
# Renamed: 000020.png -> a_city_traffic_light_is_red_with_a_large_billow_of.png
# Renamed: 000021.png -> a_city_with_many_people_waiting_for_a_train.png
# Renamed: 000022.png -> a_city_with_tall_buildings_filled_with_tall_buildi.png
# Renamed: 000023.png -> a_classic_car_parked_next_to_a_large_metal_canadia.png
# Renamed: 000024.png -> a_clock_is_shown_on_a_wood_panel.png
# Renamed: 000025.png -> a_close_up_of_a_hawk_with_a_group_of_people_in_the.png
# Renamed: 000026.png -> a_close_up_of_an_orange_in_a_red_serving_bowl.png
# Renamed: 000027.png -> a_collection_of_artwork_leaning_against_a_wooden_f.png
# Renamed: 000028.png -> a_commercial_airplane_at_the_gate_being_serviced.png
# Renamed: 000029.png -> a_couple_of_little_girls_standing_in_front_of_a_me.png
# Renamed: 000030.png -> a_couple_of_wooden_benches_sitting_across_from_eac.png
# Renamed: 000031.png -> a_couple_snugging_together_on_a_wooden_bench.png
# Renamed: 000032.png -> a_crowd_of_people_unloading_from_a_long_train.png
# Renamed: 000033.png -> a_decorative_space_with_yellow_ceramics_and_a_vase.png
# Renamed: 000034.png -> a_dog_is_chasing_after_three_running_sheep.png
# Renamed: 000035.png -> a_dog_out_in_a_field_with_a_herd_of_sheep.png
# Renamed: 000036.png -> a_fire_burns_while_a_person_rides_a_green_motorcyc.png
# Renamed: 000037.png -> a_fire_hydrant_sitting_on_the_side_of_a_city_stree.png
# Renamed: 000038.png -> a_flock_of_doves_and_a_man_sitting_in_a_park.png
# Renamed: 000039.png -> a_forest_filled_with_lush_green_leafy_trees.png
# Renamed: 000040.png -> a_giraffe_bust_hanging_by_a_rain_forest_cafe_sign.png
# Renamed: 000041.png -> a_giraffe_grazing_from_a_tree_with_rock_wall_in_ba.png
# Renamed: 000042.png -> a_giraffe_grazing_from_tree_with_brick_wall_in_bac.png
# Renamed: 000043.png -> a_giraffe_in_front_of_a_large_amount_of_plant_life.png
# Renamed: 000044.png -> a_giraffe_running_across_a_grass_covered_field.png
# Renamed: 000045.png -> a_giraffe_standing_alone_next_to_some_trees.png
# Renamed: 000046.png -> a_giraffe_standing_next_to_a_brick_building.png
# Renamed: 000047.png -> a_giraffe_walks_on_the_tundra_tree_lined_park.png
# Renamed: 000048.png -> a_girl_holding_a_skewer_with_a_banana_on_the_end.png
# Renamed: 000049.png -> a_goat_standing_next_to_a_tree_in_the_open.png
# Renamed: 000050.png -> a_goat_with_very_long_horns_standing_in_front_of_a.png
# Renamed: 000051.png -> a_green_street_sign_on_top_of_a_metal_pool.png
# Renamed: 000052.png -> a_green_street_sign_sitting_below_a_large_tree.png
# Renamed: 000053.png -> a_grey_and_white_bird_in_a_swampy_marsh.png
# Renamed: 000054.png -> a_group_of_sheep_being_herded_by_a_black_dog.png
# Renamed: 000055.png -> a_group_of_young_men_standing_outside_of_a_subway.png
# Renamed: 000056.png -> a_herd_of_animals_grazing_on_the_side_of_a_green_h.png
# Renamed: 000057.png -> a_large_airplane_flying_over_a_lush_green_hillside.png
# Renamed: 000058.png -> a_large_blue_bench_sitting_next_to_bottles.png
# Renamed: 000059.png -> a_large_bus_is_parked_outside_a_building.png
# Renamed: 000060.png -> a_large_filled_with_lots_of_purple_flowers_behind.png
# Renamed: 000061.png -> a_large_stone_bench_sitting_next_to_rose_bushes.png
# Renamed: 000062.png -> a_line_of_decorative_benches_on_a_boardwalk.png
# Renamed: 000063.png -> a_lot_of_people_that_have_some_animals.png
# Renamed: 000064.png -> a_luxurious_bathtub_in_front_of_a_window_with_a_re.png
# Renamed: 000065.png -> a_man_holding_a_bottle_and_a_group_of_people_near.png
# Renamed: 000066.png -> a_man_riding_a_bike_down_a_dark_city_street.png
# Renamed: 000067.png -> a_man_sitting_on_a_wooden_bench_near_a_lake.png
# Renamed: 000068.png -> a_man_standing_next_to_a_motorcycle_on_the_side_of.png
# Renamed: 000069.png -> a_man_standing_next_to_an_elephant_who_stole_his_h.png
# Renamed: 000070.png -> a_man_that_is_standing_in_the_street_near_a_bus.png
# Renamed: 000071.png -> a_man_wearing_a_black_hat_and_a_red_neck_tie.png
# Renamed: 000072.png -> a_modern_transportation_building_with_busses_lined.png
# Renamed: 000073.png -> a_motorcycle_being_displayed_on_a_platform_during.png
# Renamed: 000074.png -> a_motorcycle_is_on_display_at_a_convention.png
# Renamed: 000075.png -> a_motorcycle_is_parked_in_the_gravel_alongside_a_s.png
# Renamed: 000076.png -> a_motorcycle_parked_in_front_of_a_graffiti_covered.png
# Renamed: 000077.png -> a_myriad_of_stop_signs_that_are_black_and_white_an.png
# Renamed: 000078.png -> a_night_time_image_of_a_very_wide_and_crowded_city.png
# Renamed: 000079.png -> a_old_bench_next_to_an_old_building.png
# Renamed: 000080.png -> a_painting_of_a_man_herding_sheep_in_the_field.png
# Renamed: 000081.png -> a_painting_of_a_yellow_train_car_sitting_on_train.png
# Renamed: 000082.png -> a_parade_on_a_street_with_several_officers_on_moto.png
# Renamed: 000083.png -> a_person_holding_a_skateboard_overlooks_a_dead_fie.png
# Renamed: 000084.png -> a_person_is_driving_a_speedboat_quickly_through_th.png
# Renamed: 000085.png -> a_person_is_watching_two_basketball_games_at_once.png
# Renamed: 000086.png -> a_person_riding_a_motorcycle_down_a_rural_country.png
# Renamed: 000087.png -> a_person_standing_next_to_a_bike_covered_in_flower.png
# Renamed: 000088.png -> a_person_that_is_sitting_on_a_bench.png
# Renamed: 000089.png -> a_picture_of_a_lot_of_motorcycles_together.png
# Renamed: 000090.png -> a_piece_of_cake_sits_on_the_paper_plate.png
# Renamed: 000091.png -> a_pine_apple_on_top_of_a_pile_of_mixed_fruit.png
# Renamed: 000092.png -> a_plan_sitting_on_top_of_a_sandy_beach.png
# Renamed: 000093.png -> a_pond_with_various_birds_and_ducks_swimming.png
# Renamed: 000094.png -> a_rain_soaked_pigeon_sitting_on_a_fence.png
# Renamed: 000095.png -> a_red_fire_hydrant_sitting_on_a_slab_of_cement_in.png
# Renamed: 000096.png -> a_red_helmet_is_on_a_yellow_toilet_in_the_dirt.png
# Renamed: 000097.png -> a_red_stop_light_across_from_a_brick_building.png
# Renamed: 000098.png -> a_red_stop_sign_in_front_of_a_small_house_surround.png
# Renamed: 000099.png -> a_restaurant_kitchen_with_two_giant_menus_sitting.png
# Renamed: 000100.png -> a_sheet_cake_with_a_farm_scene_on_top_of_it.png
# Renamed: 000101.png -> a_shelving_unit_containing_items_next_to_a_vegetab.png
# Renamed: 000102.png -> a_sign_in_the_grass_stating_the_next_highway.png
# Renamed: 000103.png -> a_sign_next_to_a_stone_wall_stating_the_road_name.png
# Renamed: 000104.png -> a_silver_spoon_sitting_on_top_of_an_unknown_surfac.png
# Renamed: 000105.png -> a_single_engine_plane_in_the_air_right_above_a_gra.png
# Renamed: 000106.png -> a_small_black_sign_on_the_refrigerator_door.png
# Renamed: 000107.png -> a_small_bulding_is_lit_up_in_the_dark_night.png
# Renamed: 000108.png -> a_small_dog_on_tv_behind_the_words_what_did_i_do.png
# Renamed: 000109.png -> a_small_dog_on_a_leach_sitting_near_a_window.png
# Renamed: 000110.png -> a_spinning_wheel_and_hutch_by_window_at_night.png
# Renamed: 000111.png -> a_statue_of_a_giraffe_in_a_park_setting.png
# Renamed: 000112.png -> a_stop_and_street_sign_on_the_side_of_the_street.png
# Renamed: 000113.png -> a_street_covered_in_pink_confetti_next_to_a_red_fi.png
# Renamed: 000114.png -> a_street_sign_on_a_city_street_with_tall_buildings.png
# Renamed: 000115.png -> a_street_sign_surrounded_by_a_crowd_of_people.png
# Renamed: 000116.png -> a_street_view_of_tall_buildings_street_lights_and.png
# Renamed: 000117.png -> a_tolley_car_on_a_brick_street_in_an_urban_area.png
# Renamed: 000118.png -> a_tree_has_a_no_parking_sign_taped_to_its_trunk.png
# Renamed: 000119.png -> a_very_skinny_red_fire_hydrant_with_silver_top_and.png
# Renamed: 000120.png -> a_water_stained_cathedral_clock_tower_enveloped_by.png
# Renamed: 000121.png -> a_white_an_blue_fire_hydrant_on_grassy_yard_next_t.png
# Renamed: 000122.png -> a_white_and_blue_bird_is_perched_on_a_tree_branch.png
# Renamed: 000123.png -> a_white_bowl_filled_with_leafy_greens_on_a_rain_so.png
# Renamed: 000124.png -> a_white_parrot_standing_next_to_a_jungle_covered_h.png
# Renamed: 000125.png -> a_white_train_car_lays_on_its_side_in_the_dark_whi.png
# Renamed: 000126.png -> a_wildebeest_walking_with_a_giraffe_in_the_distanc.png
# Renamed: 000127.png -> a_woman_under_an_umbrella_on_a_rainy_day.png
# Renamed: 000128.png -> a_women_who_is_standing_by_a_barb_wire_fence.png
# Renamed: 000129.png -> a_wooden_bench_has_a_company_advertise_on_it.png
# Renamed: 000130.png -> a_wooden_bench_is_under_the_shade_of_a_large_tree.png
# Renamed: 000131.png -> a_wooden_bench_on_a_fence_and_plants_surrounding_i.png
# Renamed: 000132.png -> a_wooden_bench_sitting_in_a_park_covered_with_leav.png
# Renamed: 000133.png -> a_wooden_bench_sitting_in_front_of_a_park.png
# Renamed: 000134.png -> a_wooden_bench_sitting_up_against_a_lush_green_par.png
# Renamed: 000135.png -> a_wooden_floored_room_with_various_chairs_around_i.png
# Renamed: 000136.png -> a_yellow_bench_sitting_in_a_field_next_to_trees_an.png
# Renamed: 000137.png -> a_yellow_street_sign_sitting_on_the_side_of_a_road.png
# Renamed: 000138.png -> a_yellow_train_traveling_down_tracks_surrounded_by.png
# Renamed: 000139.png -> a_young_girl_walking_through_a_flower_garden.png
# Renamed: 000140.png -> a_zebra_and_giraffe_that_is_in_the_dirt.png
# Renamed: 000141.png -> an_adult_and_baby_giraffe_walking_through_a_field.png
# Renamed: 000142.png -> an_airplane_sitting_on_the_water_parked_at_the_doc.png
# Renamed: 000143.png -> an_asian_city_is_all_lit_up_in_the_dark.png
# Renamed: 000144.png -> an_old_rickety_wooden_bench_near_the_woods.png
# Renamed: 000145.png -> an_old_luncheonette_sign_on_a_corner_by_a_street_s.png
# Renamed: 000146.png -> an_old_toilet_outside_against_an_old_painted_wall.png
# Renamed: 000147.png -> an_old_train_moving_on_a_train_track.png
# Renamed: 000148.png -> an_orange_sign_that_has_a_picture_of_a_man_holding.png
# Renamed: 000149.png -> an_overview_picture_of_a_street_at_night.png
# Renamed: 000150.png -> baskets_of_oranges_and_a_basket_of_pears.png
# Renamed: 000151.png -> benches_surround_a_pond_in_a_park_in_autumn.png
# Renamed: 000152.png -> birds_with_long_legs_walking_in_the_water_near_a_b.png
# Renamed: 000153.png -> black_motorcycle_sitting_outside_a_wooden_door_on.png
# Renamed: 000154.png -> cars_have_stopped_for_a_red_light_at_the_top_of_a.png
# Renamed: 000155.png -> commode_in_brightly_lit_area_of_old_building.png
# Renamed: 000156.png -> crowds_of_people_have_lined_a_street_to_watch_a_pa.png
# Renamed: 000157.png -> flock_of_ducks_standing_on_a_rocky_shore.png
# Renamed: 000158.png -> four_mountain_goats_standing_on_a_hill_in_front_of.png
# Renamed: 000159.png -> giraffe_standing_in_the_shade_of_a_tall_covering.png
# Renamed: 000160.png -> giraffe_standing_next_to_each_other_at_a_zoo.png
# Renamed: 000161.png -> giraffe_standing_on_a_grass_covered_field_next_to.png
# Renamed: 000162.png -> graffiti_stains_the_surface_of_a_green_and_white_s.png
# Renamed: 000163.png -> i_am_unable_to_see_the_image_above.png
# Renamed: 000164.png -> large_clock_tower_overlooking_a_busy_street_during.png
# Renamed: 000165.png -> many_flowers_are_decorated_outside_of_a_building.png
# Renamed: 000166.png -> motorcyclists_are_gathered_around_their_bikes_at_a.png
# Renamed: 000167.png -> pair_of_giraffes_standing_next_to_a_wooden_pole_ba.png
# Renamed: 000168.png -> people_are_gathered_under_a_female_impersonators_s.png
# Renamed: 000169.png -> people_are_hiding_under_colorful_umbrellas_on_a_ra.png
# Renamed: 000170.png -> people_are_working_their_way_through_busy_traffic.png
# Renamed: 000171.png -> people_fly_kites_and_try_other_activities_in_a_par.png
# Renamed: 000172.png -> people_standing_next_to_tree_looking_at_an_airplan.png
# Renamed: 000173.png -> photograph_of_an_outdoors_zone_that_looks_unbeliev.png
# Renamed: 000174.png -> several_people_helping_to_load_luggage_onto_a_trai.png
# Renamed: 000175.png -> several_young_boys_sitting_in_the_library_using_la.png
# Renamed: 000176.png -> sheep_in_a_forest_after_the_snow_has_melted.png
# Renamed: 000177.png -> there_are_animals_that_are_grassing_in_the_field.png
# Renamed: 000178.png -> the_giraffes_are_almost_camouflaged_in_the_terrain.png
# Renamed: 000179.png -> the_bathroom_is_adorned_with_green_rugs_and_a_gree.png
# Renamed: 000180.png -> the_car_is_traveling_down_the_road_while_the_dog_w.png
# Renamed: 000181.png -> the_city_is_filled_with_one_way_streets.png
# Renamed: 000182.png -> the_traffic_in_this_city_is_busy_this_time_of_day.png
# Renamed: 000183.png -> the_wooden_bench_is_near_a_busy_stream.png
# Renamed: 000184.png -> there_are_a_lot_of_animals_on_the_hills.png
# Renamed: 000185.png -> there_are_a_lot_of_trees_and_plants_beside_the_hou.png
# Renamed: 000186.png -> there_is_a_lot_of_graffiti_on_the_train_cart.png
# Renamed: 000187.png -> these_are_a_few_animals_out_in_a_field.png
# Renamed: 000188.png -> this_is_a_thing_that_is_straightforward_and_plain.png
# Renamed: 000189.png -> this_is_what_is_left_of_a_kitchen_in_an_abandoned.png
# Renamed: 000190.png -> three_adult_giraffe_stand_at_a_grove_of_trees.png
# Renamed: 000191.png -> three_giraffes_are_next_to_a_cage_of_green_food.png
# Renamed: 000192.png -> three_men_sitting_on_motorcycles_on_a_sidewalk.png
# Renamed: 000193.png -> three_sheep_in_a_vineyard_two_black_faced_and_one.png
# Renamed: 000194.png -> two_birds_that_are_sitting_next_to_each_other.png
# Renamed: 000195.png -> two_ducklings_sit_next_to_each_other_in_grass.png
# Renamed: 000196.png -> two_giraffe_standing_next_to_each_other_on_a_lush.png
# Renamed: 000197.png -> two_giraffes_move_around_in_an_enclosure_next_to_s.png
# Renamed: 000198.png -> two_giraffes_standing_in_grass_surrounded_by_trees.png
# Renamed: 000199.png -> two_motorcycles_parked_in_a_grassy_area_next_to_a.png
# Renamed: 000200.png -> two_people_are_kissing_as_they_sit_on_a_bench.png
# Renamed: 000201.png -> two_people_are_looking_in_a_mirror_near_a_traffic.png
# Renamed: 000202.png -> two_people_standing_next_to_a_motorcycle_on_a_bric.png
# Renamed: 000203.png -> two_street_signs_read_dead_end_and_college.png
# Renamed: 000204.png -> water_is_spewing_form_the_ground_while_people_watc.png
# Renamed: 000205.png -> wild_animals_grazing_near_a_lagoon_surrounded_by_t.png
# Renamed: 000206.png -> women_father_around_a_desk_and_machinery_in_a_fact.png
# Renamed: 000207.png -> many_tables_arranged_outside_at_the_shop.png
# Renamed: 000208.png -> a_bench_sitting_by_a_wall_and_surrounded_by_purpl.png
# Renamed: 000209.png -> a_brown_brick_house_with_so_many_windows.png
# Renamed: 000210.png -> a_close_up_of_a_giraffe_behind_a_fence.png
# Renamed: 000211.png -> a_close_up_of_a_street_sign_near_a_building.png
# Renamed: 000212.png -> a_close_up_of_graffiti_written_on_a_train.png
# Renamed: 000213.png -> a_giraffe_leaning_over_a_fence_to_eat_out_of_a_bow.png
# Renamed: 000214.png -> a_number_of_animals_in_a_field_near_some_trees.png
# Renamed: 000215.png -> a_number_of_motorcycles_in_a_lot.png
# Renamed: 000216.png -> a_red_and_blue_fire_hydrant_and_people_walking_in.png
# Renamed: 000217.png -> a_train_near_a_platform_and_people_walking.png
# Renamed: 000218.png -> a_woman_sitting_on_a_picnic_table_on_her_cell_phon.png
# Renamed: 000219.png -> a_woman_sitting_on_a_wooden_park_bench_smiling_at.png
# Renamed: 000220.png -> black_and_white_photo_of_two_birds_flying_on_a_clo.png
# Renamed: 000221.png -> several_men_on_a_street_corner_repairing_a_street.png
# Renamed: 000222.png -> there_is_a_small_dog_that_is_looking_threw_the_gla.png
# Renamed: 000223.png -> this_kitchen_is_very_big_and_has_wood_cainets.png
# Renamed: 000224.png -> trees_in_fall_colors_and_a_stop_sign_to_the_right.png
